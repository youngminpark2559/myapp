# %%
import requests
from bs4 import BeautifulSoup
import json
import re

# %%
def videolistwithtitle(startpage,lastpage):
    for i in list(range(int(startpage), int(lastpage)+1)):
        addressholder = []
        url = 'https://channel9.msdn.com/Browse/AllContent?page='+str(i)+'&lang=en'
        r=requests.get(url)
        c=r.content
        soup=BeautifulSoup(c, "html.parser")
        # re = BeautifulSoup(r.text)

        videolist=soup.select('h3 > a[href]')
        print('\npage'+str(i))
        for onevideo in videolist:
            refinedaddress = str(onevideo).replace('<a href="', 'https://channel9.msdn.com/')\
            .replace('">',  '\nabove video\'s title : ').replace('</a>','')
            print(refinedaddress)

# %%
def videolistwithouttitle(startpage, lastpage):
    for i in list(range(int(startpage), int(lastpage)+1)):
        addressholder = []
        url = 'https://channel9.msdn.com/Browse/AllContent?page='+str(i)+'&lang=en'
        r=requests.get(url)
        c=r.content
        soup=BeautifulSoup(c, "html.parser")
        # re = BeautifulSoup(r.text)

        videolist=soup.select('h3 > a[href]')
        print('\npage'+str(i))

        listHolder = []

        for onevideo in videolist:
            refinedaddress = str(onevideo).replace('<a href="', 'https://channel9.msdn.com/')\
               .replace('">',  '\nabove video\'s title : ')\
               .replace('</a>','')
            listremovedtitle = re.sub(r'(above video).*', '', refinedaddress)
            print(listremovedtitle)

# %%
def videolistwithMp3list(startpage, lastpage):
    for i in list(range(int(startpage), int(lastpage)+1)):
        addressholder = []
        url = 'https://channel9.msdn.com/Browse/AllContent?page='+str(i)+'&lang=en'
        r=requests.get(url)
        c=r.content
        soup=BeautifulSoup(c, "html.parser")
        # re = BeautifulSoup(r.text)

        videolist=soup.select('h3 > a[href]')
        print('\npage'+str(i))

        for onevideo in videolist:
            refinedaddress = str(onevideo).replace('<a href="', 'https://channel9.msdn.com/')\
            .replace('">',  '\nabove video\'s title : ')\
            .replace('</a>','')
            listremovedtitle = re.sub(r'(above video).*', '', refinedaddress).strip()
            # print(listremovedtitle)
            
            refinedaddressPage=requests.get(listremovedtitle)
            refinedaddressPageContents = refinedaddressPage.content
            soupForrefinedaddressPageContents = BeautifulSoup(refinedaddressPageContents, "html.parser")
            
            # I find mp3 address by index
            # mediaList = soupForrefinedaddressPageContents.find_all("div", {"class":"download"})
            # for media in mediaList:
            #     mp3Address = media.select('li > a[href]')
            #     splitedByHref = str(mp3Address[0]).split('href')
            #     oneMp3 = str(splitedByHref).strip().split('>')[0].split('\'="')[1].replace('mp3"', 'mp3')
            #     print(oneMp3)

            # I find mp3 address by regular expression
            mediaList = soupForrefinedaddressPageContents.find_all("div", {"class":"download"})
            for media in mediaList:
                mediaAddress = str(media.select('li > a[href]'))
                try:
                    extractedMp3 = re.match('.*(mp3)', mediaAddress).group(0)
                    print(str(extractedMp3).split('href="')[1])
                except:
                    pass

# %%
if __name__ == '__main__':
    titleNonTitleMp3 = int(input('video list+title(1), video list(2), video list+mp3 list(3): '))
    if titleNonTitleMp3 == 1:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithtitle(startpage, lastpage)
    elif titleNonTitleMp3 == 2:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithouttitle(startpage, lastpage)
    elif titleNonTitleMp3 == 3:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithMp3list(startpage, lastpage)
# Out:
# page1
# https://channel9.msdn.com//Shows/Tuesdays-With-Corey/Open-Sourcing-Microsoft-Service-Fabric
# above video's title : Open Sourcing Microsoft Service Fabric
# https://channel9.msdn.com//Shows/Level-Up/Building-Windows-MR-Apps-with-Unity
# above video's title : Building Windows MR Apps with Unity
# https://channel9.msdn.com//Shows/Level-Up/Mixer-Interview-of-the-Game-Hyper-Sentinel
# above video's title : Mixer Interview of the Game Hyper Sentinel
# https://channel9.msdn.com//Shows/The-Open-Source-Show/Part-4-of-4-Use-Azure-Container-Registry
# above video's title : Part 4 of 4: Use Azure Container Registry
# https://channel9.msdn.com//Shows/On-NET/Building-distributed-applications-with-AkkaNET
# above video's title : Building distributed applications with Akka.NET
# https://channel9.msdn.com//Shows/Level-Up/Continuously-Test-distribute-and-monitor-your-game-with-App-Center-Theater-Presentation
# above video's title : Continuously Test, distribute and monitor your game with App Center - Theater Presentation
# https://channel9.msdn.com//Shows/Level-Up/Planning-and-building-games-using-the-full-power-of-VSTS-Agile-CI--CD-end-to-end-demo
# above video's title : Planning and building games using the full power of VSTS: Agile, CI &amp; CD end-to-end demo
# https://channel9.msdn.com//Shows/Level-Up/Your-game-everywhere-PlayFab
# above video's title : Your game, everywhere - PlayFab
# https://channel9.msdn.com//Shows/Level-Up/Azure-Container-Instances-for-Multiplayer-Gaming-Theater
# above video's title : Azure Container Instances for Multiplayer Gaming - Theater Presentation
# https://channel9.msdn.com//Shows/Level-Up/Get-massive-promotion-for-minimal-effort-with-Mixer-Theater-presentation
# above video's title : Get massive promotion for minimal effort with Mixer - Theater presentation
# https://channel9.msdn.com//Shows/Level-Up/Microsoft-Store-How-You-Can-Reach-Xbox-One-and-Windows-10-users
# above video's title : Microsoft Store: How You Can Reach Xbox One and Windows 10 users
# https://channel9.msdn.com//Shows/Level-Up/Why-Candy-Crush-on-Windows-10-and-in-Microsoft-Store
# above video's title : Why Candy Crush on Windows 10 and in Microsoft Store
#
# page2
# https://channel9.msdn.com//Shows/Level-Up/Building-Astroneer-Charting-new-and-challenging-courses
# above video's title : Building Astroneer: Charting new and challenging courses
# https://channel9.msdn.com//Shows/Level-Up/Xbox-Live-Creators-Program-Jumpstart-for-Unity-Developers
# above video's title : Xbox Live Creators Program Jumpstart for Unity Developers
# https://channel9.msdn.com//Shows/On-NET/Debugging-and-Diagnostics-of-Durable-Functions
# above video's title : Debugging and Diagnostics of Durable Functions
# https://channel9.msdn.com//Shows/Azure-Friday/Azure-Visual-Studio-Xamarin-Great-mobile-apps
# above video's title : Azure + Visual Studio + Xamarin = Great Mobile Apps
# https://channel9.msdn.com//Shows/Level-Up/Your-game-every-way-its-played-PlayFab-Theater-Presentation
# above video's title : Your game, every way it's played: PlayFab - Theater Presentation
# https://channel9.msdn.com//Shows/Level-Up/Build-your-next-game-powered-by-Visual-Studio-Team-Services-and-Unity-Teams-cloud-build-Theater
# above video's title : Build your next game powered by Visual Studio Team Services and Unity Teams cloud build -…
# https://channel9.msdn.com//Shows/Level-Up/How-The-Walking-Dead-No-Mans-Land-was-built-to-scale-on-Azure-Theater-Presentation
# above video's title : How The Walking Dead No Man's Land was built to scale on Azure - Theater Presentation
# https://channel9.msdn.com//Shows/Level-Up/Running-on-a-Hypervisor-Theater-Presentation
# above video's title : Running on a Hypervisor - Theater Presentation
# https://channel9.msdn.com//Shows/Level-Up/Containers-Clusters-and-the-Cloud-for-Gaming-Theater-Presentation-1
# above video's title : Containers, Clusters and the Cloud for Gaming - Theater Presentation 1
# https://channel9.msdn.com//Shows/Level-Up/The-AR-Cloud-Why-the-future-of-MR-is-not-a-device-itsall-of-them
# above video's title : The AR Cloud: Why the future of MR is not a device, it's all of them
# https://channel9.msdn.com//Shows/Level-Up/Azure-Cosmos-DB-Comprehensive-Overview
# above video's title : Azure Cosmos DB: Comprehensive Overview
# https://channel9.msdn.com//Shows/Level-Up/Photogrammetry-and-Laser-Scanning-in-Forza-Motorsport-7-Theater-Presentation-1
# above video's title : Photogrammetry and Laser Scanning in Forza Motorsport 7 - Theater Presentation 1

# %%
if __name__ == '__main__':
    titleNonTitleMp3 = int(input('video list+title(1), video list(2), video list+mp3 list(3): '))
    if titleNonTitleMp3 == 1:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithtitle(startpage, lastpage)
    elif titleNonTitleMp3 == 2:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithouttitle(startpage, lastpage)
    elif titleNonTitleMp3 == 3:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithMp3list(startpage, lastpage)
# Out:
# page1
# https://channel9.msdn.com//Shows/Tuesdays-With-Corey/Open-Sourcing-Microsoft-Service-Fabric
#
# https://channel9.msdn.com//Shows/Level-Up/Building-Windows-MR-Apps-with-Unity
#
# https://channel9.msdn.com//Shows/Level-Up/Mixer-Interview-of-the-Game-Hyper-Sentinel
#
# https://channel9.msdn.com//Shows/The-Open-Source-Show/Part-4-of-4-Use-Azure-Container-Registry
#
# https://channel9.msdn.com//Shows/On-NET/Building-distributed-applications-with-AkkaNET
#
# https://channel9.msdn.com//Shows/Level-Up/Continuously-Test-distribute-and-monitor-your-game-with-App-Center-Theater-Presentation
#
# https://channel9.msdn.com//Shows/Level-Up/Planning-and-building-games-using-the-full-power-of-VSTS-Agile-CI--CD-end-to-end-demo
#
# https://channel9.msdn.com//Shows/Level-Up/Your-game-everywhere-PlayFab
#
# https://channel9.msdn.com//Shows/Level-Up/Azure-Container-Instances-for-Multiplayer-Gaming-Theater
#
# https://channel9.msdn.com//Shows/Level-Up/Get-massive-promotion-for-minimal-effort-with-Mixer-Theater-presentation
#
# https://channel9.msdn.com//Shows/Level-Up/Microsoft-Store-How-You-Can-Reach-Xbox-One-and-Windows-10-users
#
# https://channel9.msdn.com//Shows/Level-Up/Why-Candy-Crush-on-Windows-10-and-in-Microsoft-Store
#
#
# page2
# https://channel9.msdn.com//Shows/Level-Up/Building-Astroneer-Charting-new-and-challenging-courses
#
# https://channel9.msdn.com//Shows/Level-Up/Xbox-Live-Creators-Program-Jumpstart-for-Unity-Developers
#
# https://channel9.msdn.com//Shows/On-NET/Debugging-and-Diagnostics-of-Durable-Functions
#
# https://channel9.msdn.com//Shows/Azure-Friday/Azure-Visual-Studio-Xamarin-Great-mobile-apps
#
# https://channel9.msdn.com//Shows/Level-Up/Your-game-every-way-its-played-PlayFab-Theater-Presentation
#
# https://channel9.msdn.com//Shows/Level-Up/Build-your-next-game-powered-by-Visual-Studio-Team-Services-and-Unity-Teams-cloud-build-Theater
#
# https://channel9.msdn.com//Shows/Level-Up/How-The-Walking-Dead-No-Mans-Land-was-built-to-scale-on-Azure-Theater-Presentation
#
# https://channel9.msdn.com//Shows/Level-Up/Running-on-a-Hypervisor-Theater-Presentation
#
# https://channel9.msdn.com//Shows/Level-Up/Containers-Clusters-and-the-Cloud-for-Gaming-Theater-Presentation-1
#
# https://channel9.msdn.com//Shows/Level-Up/The-AR-Cloud-Why-the-future-of-MR-is-not-a-device-itsall-of-them
#
# https://channel9.msdn.com//Shows/Level-Up/Azure-Cosmos-DB-Comprehensive-Overview
#
# https://channel9.msdn.com//Shows/Level-Up/Photogrammetry-and-Laser-Scanning-in-Forza-Motorsport-7-Theater-Presentation-1

# %%
if __name__ == '__main__':
    titleNonTitleMp3 = int(input('video list+title(1), video list(2), video list+mp3 list(3): '))
    if titleNonTitleMp3 == 1:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithtitle(startpage, lastpage)
    elif titleNonTitleMp3 == 2:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithouttitle(startpage, lastpage)
    elif titleNonTitleMp3 == 3:
        startpage = input('start page: ')
        lastpage = input('last page: ')
        videolistwithMp3list(startpage, lastpage)
# Out:
# page1
# https://sec.ch9.ms/ch9/852a/798f94c9-f8b5-427c-b5d2-f8e9a7b1852a/007BuildingWindowsMRAppsWithUnity.mp3
# https://sec.ch9.ms/ch9/e9a0/4818cc19-4034-4831-b705-1f1324a2e9a0/GDCLiveDay2HueyGames.mp3
# https://sec.ch9.ms/ch9/90f6/d6d3aecc-eb93-4e8d-b85f-9d7e51be90f6/20180328-OnNET.mp3
# https://sec.ch9.ms/ch9/a101/b326c4e3-990c-4b71-9d1c-67255b3fa101/23ContinuouslyTestDistributeMonitorYourGameAppCen.mp3
# https://sec.ch9.ms/ch9/c86c/de08154d-047e-4b55-8c02-15fe458dc86c/008PlanningAndBuildingGamesUsingFullPowerVSTS.mp3
# https://sec.ch9.ms/ch9/625c/ade07df9-f700-4b11-8496-56f902ad625c/002YourGameEverywherePlayFab.mp3
# https://sec.ch9.ms/ch9/f028/e3eb1a83-6177-4de9-96bb-c47e5cb8f028/022AzureContainerInstancesforMultiplayerGaming.mp3
# https://sec.ch9.ms/ch9/a9eb/414eff06-c66a-484d-8a1e-c8858f1ea9eb/009GetMassivePromotionForMinimalEffortWithMixer.mp3
# https://sec.ch9.ms/ch9/4475/e2e055d4-9e54-438e-9e60-ef226f284475/006MicrosoftStoreHowYouCanReachXboxOneWin10Users.mp3
# https://sec.ch9.ms/ch9/a01d/f87bab34-94c6-4c96-9695-45d57440a01d/001WhyCandyCrushonWin10.mp3
#
# page2
# https://sec.ch9.ms/ch9/ecf5/af746b12-b80d-42b9-9454-ee5815c0ecf5/005BuildingAstroneer.mp3
# https://sec.ch9.ms/ch9/6929/65f33e3f-6398-4c86-b762-8f9ac8d56929/24XboxLiveCreatorsProgramJumpstartForUnityDevs.mp3
# https://sec.ch9.ms/ch9/8b03/40bf2836-6946-4a0c-8804-e40130978b03/20180327-OnNET.mp3
# https://sec.ch9.ms/ch9/f362/e15dd48b-7384-4665-a886-0315be63f362/AzureFridayVisualStudioXamarinAzure.mp3
# https://sec.ch9.ms/ch9/aad4/0fffe723-edc9-4422-bf24-afb7ef53aad4/29YourGameEveryWayItsPlayedPlayfab.mp3
# https://sec.ch9.ms/ch9/26d5/e26512ab-f0bb-48b9-834b-3f7bb38c26d5/27BuildYourNextGamePoweredByVSTS.mp3
# https://sec.ch9.ms/ch9/3de7/80d52d22-851b-44ab-bdfa-6a8039513de7/26HowWalkingDeadNoMansLandBuiltToScaleOnAzure.mp3
# https://sec.ch9.ms/ch9/d4ae/ba799c07-3865-44be-baf7-28a03f8dd4ae/25RunningOnAHypervisor.mp3
# https://sec.ch9.ms/ch9/d6f2/90849022-275b-42d1-a34b-5d816f1ad6f2/021ContainersClustersCloudForGaming.mp3
# https://sec.ch9.ms/ch9/7648/f3f1a37c-4ed8-4772-916e-f4b188b67648/020TheARCloudWhyTheFutureofMRisNotaDevice.mp3
# https://sec.ch9.ms/ch9/0a0f/bbbf8a76-32cf-4e6c-a1ca-2df6ffe10a0f/019AzureCosmosDBComprehensiveOverview.mp3
# https://sec.ch9.ms/ch9/0ccb/ce760d92-dd76-4753-8e05-a9d4dc0d0ccb/016PhotogrammetryLaserScanningInForza.mp3
